# %%
import pandas as pd
import numpy as np

# %%
url = "https://raw.githubusercontent.com/campusx-official/placement-project-logistic-regression/refs/heads/main/placement.csv"
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df = df.drop(columns="Unnamed: 0",axis = 1)

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 3)

# %%
df.isnull().sum()
# Out:
# cgpa         0
# iq           0
# placement    0
# dtype: int64

# %%
df.iloc[:,0:]
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %%
plt.scatter(df["cgpa"],df['iq'],c = df["placement"])
plt.xlabel("CGPA")
plt.ylabel("Iq")

plt.show()

# %%
plt.boxplot(df["iq"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21f9a35dbe0>,
#   <matplotlib.lines.Line2D at 0x21f9a35dd30>],
#  'caps': [<matplotlib.lines.Line2D at 0x21f9a35de80>,
#   <matplotlib.lines.Line2D at 0x21f9a35dfd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21f9a35da90>],
#  'medians': [<matplotlib.lines.Line2D at 0x21f9a35e120>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21f9a35e270>],
#  'means': []}

# %%
x = df.drop(columns = "placement",axis=1)
y = df["placement"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test =  train_test_split(x,y,test_size=0.1,random_state = 42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(y_test,y_pred)

# %%
acc
# Out:
# 0.8

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x_train, y_train.values, clf=model)
# Out:
# <Axes: >

# %%
#after this pickle file
